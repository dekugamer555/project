# %%
eng = {"romance" : [
    "Eternal Sunshine of the Spotless Mind",
    "About Time",
    "The Proposal",
    "500 Days of Summer",
    "Crazy, Stupid, Love.",
    "The Notebook",
    "Pride and Prejudice(2005)",
    "Silver Linings Playbook",
    "Before We Go",
    "To All the Boys I've Loved Before"],
"action": [
    "Die Hard (1988)",
    "Mad Max: Fury Road (2015)",
    "The Dark Knight (2008)",
    "Inception (2010)",
    "Gladiator (2000)",
    "John Wick (2014)",
    "Terminator 2: Judgment Day (1991)",
    "Raiders of the Lost Ark (1981)",
    "The Matrix (1999)",
    "Black Panther (2018)"],
'comedy': [
    "Superbad (2007)",
    "Groundhog Day (1993)",
    "The Big Lebowski (1998)",
    "Bridesmaids (2011)",
    "Monty Python and the Holy Grail (1975)",
    "Step Brothers (2008)",
    "Ferris Bueller's Day Off (1986)",
    "The Hangover (2009)",
    "Anchorman: The Legend of Ron Burgundy (2004)",
    "Mean Girls (2004)"],
'horror': [
    "The Autopsy of Jane Doe",
    "The Witch",
    "Hereditary",
    "Midsommar",
    "The Invisible Man",
    "Saint Maud",
    "The Night House",
    "The Taking of Deborah Logan",
    "Candyman (2021)",
    "Barbarian"
],"thriller": [
    "Nightcrawler",
    "The Gift",
    "Prisoners",
    "A Simple Favor",
    "Searching",
    "The Night House",
    "Unsane",
    "Gone Girl",
    "The Invisible Man",
    "The Little Things"
],
"wholesome": [
    "The Peanut Butter Falcon",
    "A Beautiful Day in the Neighborhood",
    "Little Miss Sunshine",
    "About Time",
    "The Farewell",
    "Chef",
    "The Intouchables",
    "The Greatest Showman",
    "Yes Day",
    "Goodbye Christopher Robin"
],
'crime' : [
    "The Invisible Man",
    "Knives Out",
    "Gone Girl",
    "Prisoners",
    "The Gift",
    "Wind River",
    "Nightcrawler",
    "The Little Things",
    "Searching",
    "The Night House"
]
}
hindi={"romance": [
    "Dilwale Dulhania Le Jayenge (1995)",
    "Kabir Singh (2019)",
    "Jab We Met (2007)",
    "Yeh Jawaani Hai Deewani (2013)",
    "Hum Dil De Chuke Sanam (1999)",
    "Aashiqui 2 (2013)",
    "Veer-Zaara (2004)",
    "Rab Ne Bana Di Jodi (2008)",
    "Pyaar Kiya To Darna Kya (1998)",
    "2 States (2014)"],
'action' :[
    "Gangs of Wasseypur",
    "Drishyam",
    "Kahaani",
    "Taanakkaran",
    "Maari",
    "Special 26",
    "Andhadhun",
    "Uri: The Surgical Strike",
    "Raazi",
    "Haider"],
'comedy' :[
    "Chupke Chupke (1975)",
    "Gol Maal (1979)",
    "Hera Pheri (2000)",
    "Munna Bhai M.B.B.S. (2003)",
    "3 Idiots (2009)",
    "PK (2014)",
    "Tanu Weds Manu (2011)",
    "Queen (2013)",
    "Pyaar Ka Punchnama (2011)",
    "Andaz Apna Apna (1994)"
],
"horror": [
    "Raat (1992)",
    "Bhoot (2003)",
    "Raaz (2002)",
    "Pari (2018)",
    "Tumbbad (2018)",
    "Stree (2018)",
    "Phobia (2016)",
    "1920 (2008)",
    "Ludo (2020) - Horror Segment",
    "Bulbbul (2020)"],
"thriller": [
    "Kahaani (2012)",
    "Andhadhun (2018)",
    "Talaash (2012)",
    "Drishyam (2015)",
    "Baazigar (1993)",
    "Ghajini (2008)",
    "Special 26 (2013)",
    "Rang De Basanti (2006)",
    "Kahaani 2 (2016)",
    "Article 15 (2019)"
],
'wholesome' : [
    "Taare Zameen Par (2007)",
    "Chhichhore (2019)",
    "Piku (2015)",
    "Queen (2013)",
    "Bajrangi Bhaijaan (2015)",
    "PK (2014)",
    "Udaan (2010)",
    "The Lunchbox (2013)",
    "Zindagi Na Milegi Dobara (2011)",
    "Masaan (2015)"
],
'crime' : [
    "Gangs of Wasseypur (2012)",
    "Kahaani (2012)",
    "Drishyam (2015)",
    "Andhadhun (2018)",
    "Talvar (2015)",
    "Paan Singh Tomar (2012)",
    "Kahaani 2 (2016)",
    "Raaz (2002)",
    "Rang De Basanti (2006)",
    "Mumbai Meri Jaan (2008)"
]
}
tamil={"romance": [
    "Mouna Raagam (1986)",
    "Kadhal (2004)",
    "Vinnaithaandi Varuvaayaa (2010)",
    "Engeyum Eppodhum (2011)",
    "Thangamagan (2015)",
    "OK Kanmani (2015)",
    "96 (2018)",
    "Premam (2015)",
    "Ethir Neechal (2013)",
    "Love Failure (2012)"],
'action' :[
    "Aaranya Kaandam",
    "Neram",
    "Vikram Vedha",
    "Kaithi",
    "Kazhugu",
    "Leo",
    "Raayan",
    "Vikram",
    "Komban",
    "Salim"],
'comedy': [
    "Dharala Prabhu",
    "Oh My Kadavule",
    "Kannaadi Poovukkum",
    "Naanum Rowdydhaan",
    "Maanagaram",
    "Kootathil Oruthan",
    "Naan Sirithal",
    "Thumbaa",
    "Karnan",
    "Bhoomi"
],
'horror' : [
    "Maya",
    "Demonte Colony",
    "Kanchana 3",
    "Petta",
    "Imaikkaa Nodigal",
    "Naa Naa",
    "Bhaagamathie",
    "Ratsasan",
    "Airaa",
    "Anakkallan"
],"thriller": [
    "Dhuruvangal Pathinaaru",
    "Kavalai Vendam",
    "Imaikkaa Nodigal",
    "Ratsasan",
    "Naanum Rowdydhaan",
    "Kaithi",
    "Thunivu",
    "Vikram Vedha",
    "Anjaam Pathiraa",
    "Kannaadi Poovukkum"
],"wholesome": [
    "Kanaa",
    "Vada Chennai",
    "Neram",
    "Kootathil Oruthan",
    "Naanum Rowdydhaan",
    "Vennila Kabadi Kuzhu",
    "Aandavan Kattalai",
    "Oh My Kadavule",
    "Maanagaram",
    "Naan Sirithal"
],
'crime' : [
    "Dhuruvangal Pathinaaru",
    "Ratsasan",
    "Thunivu",
    "Kaithi",
    "Kavalai Vendam",
    "Imaikkaa Nodigal",
    "Vikram Vedha",
    "Anjaam Pathiraa",
    "Maanagaram",
    "Maha Samudram"]
}
import random as r
choice = 'y'
while choice == 'y' or choice == 'Y':
        lan=input("what language move would you like to see(eng/hindi/tamil): ")
        g=input("what genre move would you like to see(romance,horror,comedy,wholesome,action,crime,thriller): ")
        if lan=='eng':
            for k,v in eng.items():
                if k==g:
                    print(r.choices(v,k=3),'\n')
                    break
            else:
                print('Error 404\n')

        elif lan=='hindi':
            for k,v in hindi.items():
                if k==g:
                    print(r.choices(v,k=3),'\n')
                    break
            else:
                print('Error 404\n')
        elif lan=='tamil':
            for k,v in tamil.items():
                if k==g:
                    print(r.choices(v,k=3),'\n')
                    break
            else:
                 print('Error 404\n')
                 
        else:
             print("language out of range")
        choice = input('enter your choice for more movie suggetion (y/n):')
print('thank you for use the app')
# Out:
# what language move would you like to see(eng/hindi/tamil): tamil
# what genre move would you like to see(romance,horror,comedy,wholesome,action,crime,thriller): comedy
# ['Naan Sirithal', 'Bhoomi', 'Dharala Prabhu']
#
# enter your choice for more movie suggetion (y/n):y
# what language move would you like to see(eng/hindi/tamil): hindi
# what genre move would you like to see(romance,horror,comedy,wholesome,action,crime,thriller): action
# ['Kahaani', 'Special 26', 'Uri: The Surgical Strike']
#
# enter your choice for more movie suggetion (y/n):n
# thank you for use the app
