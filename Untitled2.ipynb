# %%
import random as r
eng = {"romance" : [
    "Eternal Sunshine of the Spotless Mind",
    "About Time",
    "The Proposal",
    "500 Days of Summer",
    "Crazy, Stupid, Love.",
    "The Notebook",
    "Pride and Prejudice(2005)",
    "Silver Linings Playbook",
    "Before We Go",
    "To All the Boys I've Loved Before"],
"action": [
    "Die Hard (1988)",
    "Mad Max: Fury Road (2015)",
    "The Dark Knight (2008)",
    "Inception (2010)",
    "Gladiator (2000)",
    "John Wick (2014)",
    "Terminator 2: Judgment Day (1991)",
    "Raiders of the Lost Ark (1981)",
    "The Matrix (1999)",
    "Black Panther (2018)"],
'comedy': [
    "Superbad (2007)",
    "Groundhog Day (1993)",
    "The Big Lebowski (1998)",
    "Bridesmaids (2011)",
    "Monty Python and the Holy Grail (1975)",
    "Step Brothers (2008)",
    "Ferris Bueller's Day Off (1986)",
    "The Hangover (2009)",
    "Anchorman: The Legend of Ron Burgundy (2004)",
    "Mean Girls (2004)"],
'horror': [
    "The Autopsy of Jane Doe",
    "The Witch",
    "Hereditary",
    "Midsommar",
    "The Invisible Man",
    "Saint Maud",
    "The Night House",
    "The Taking of Deborah Logan",
    "Candyman (2021)",
    "Barbarian"
],"thriller": [
    "Nightcrawler",
    "The Gift",
    "Prisoners",
    "A Simple Favor",
    "Searching",
    "The Night House",
    "Unsane",
    "Gone Girl",
    "The Invisible Man",
    "The Little Things"
],
"wholesome": [
    "The Peanut Butter Falcon",
    "A Beautiful Day in the Neighborhood",
    "Little Miss Sunshine",
    "About Time",
    "The Farewell",
    "Chef",
    "The Intouchables",
    "The Greatest Showman",
    "Yes Day",
    "Goodbye Christopher Robin"
],
'crime' : [
    "The Invisible Man",
    "Knives Out",
    "Gone Girl",
    "Prisoners",
    "The Gift",
    "Wind River",
    "Nightcrawler",
    "The Little Things",
    "Searching",
    "The Night House"
]
}
hindi={"romance": [
    "Dilwale Dulhania Le Jayenge (1995)",
    "Kabir Singh (2019)",
    "Jab We Met (2007)",
    "Yeh Jawaani Hai Deewani (2013)",
    "Hum Dil De Chuke Sanam (1999)",
    "Aashiqui 2 (2013)",
    "Veer-Zaara (2004)",
    "Rab Ne Bana Di Jodi (2008)",
    "Pyaar Kiya To Darna Kya (1998)",
    "2 States (2014)"],
'action' :[
    "Gangs of Wasseypur",
    "Drishyam",
    "Kahaani",
    "Taanakkaran",
    "Maari",
    "Special 26",
    "Andhadhun",
    "Uri: The Surgical Strike",
    "Raazi",
    "Haider"],
'comedy' :[
    "Chupke Chupke (1975)",
    "Gol Maal (1979)",
    "Hera Pheri (2000)",
    "Munna Bhai M.B.B.S. (2003)",
    "3 Idiots (2009)",
    "PK (2014)",
    "Tanu Weds Manu (2011)",
    "Queen (2013)",
    "Pyaar Ka Punchnama (2011)",
    "Andaz Apna Apna (1994)"
],
"horror": [
    "Raat (1992)",
    "Bhoot (2003)",
    "Raaz (2002)",
    "Pari (2018)",
    "Tumbbad (2018)",
    "Stree (2018)",
    "Phobia (2016)",
    "1920 (2008)",
    "Ludo (2020) - Horror Segment",
    "Bulbbul (2020)"],
"thriller": [
    "Kahaani (2012)",
    "Andhadhun (2018)",
    "Talaash (2012)",
    "Drishyam (2015)",
    "Baazigar (1993)",
    "Ghajini (2008)",
    "Special 26 (2013)",
    "Rang De Basanti (2006)",
    "Kahaani 2 (2016)",
    "Article 15 (2019)"
],
'wholesome' : [
    "Taare Zameen Par (2007)",
    "Chhichhore (2019)",
    "Piku (2015)",
    "Queen (2013)",
    "Bajrangi Bhaijaan (2015)",
    "PK (2014)",
    "Udaan (2010)",
    "The Lunchbox (2013)",
    "Zindagi Na Milegi Dobara (2011)",
    "Masaan (2015)"
],
'crime' : [
    "Gangs of Wasseypur (2012)",
    "Kahaani (2012)",
    "Drishyam (2015)",
    "Andhadhun (2018)",
    "Talvar (2015)",
    "Paan Singh Tomar (2012)",
    "Kahaani 2 (2016)",
    "Raaz (2002)",
    "Rang De Basanti (2006)",
    "Mumbai Meri Jaan (2008)"
]
}
tamil={"romance": [
    "Mouna Raagam (1986)",
    "Kadhal (2004)",
    "Vinnaithaandi Varuvaayaa (2010)",
    "Engeyum Eppodhum (2011)",
    "Thangamagan (2015)",
    "OK Kanmani (2015)",
    "96 (2018)",
    "Premam (2015)",
    "Ethir Neechal (2013)",
    "Love Failure (2012)"],
'action' :[
    "Aaranya Kaandam",
    "Neram",
    "Vikram Vedha",
    "Kaithi",
    "Kazhugu",
    "Leo",
    "Raayan",
    "Vikram",
    "Komban",
    "Salim"],
'comedy': [
    "Dharala Prabhu",
    "Oh My Kadavule",
    "Kannaadi Poovukkum",
    "Naanum Rowdydhaan",
    "Maanagaram",
    "Kootathil Oruthan",
    "Naan Sirithal",
    "Thumbaa",
    "Karnan",
    "Bhoomi"
],
'horror' : [
    "Maya",
    "Demonte Colony",
    "Kanchana 3",
    "Petta",
    "Imaikkaa Nodigal",
    "Naa Naa",
    "Bhaagamathie",
    "Ratsasan",
    "Airaa",
    "Anakkallan"
],"thriller": [
    "Dhuruvangal Pathinaaru",
    "Kavalai Vendam",
    "Imaikkaa Nodigal",
    "Ratsasan",
    "Naanum Rowdydhaan",
    "Kaithi",
    "Thunivu",
    "Vikram Vedha",
    "Anjaam Pathiraa",
    "Kannaadi Poovukkum"
],"wholesome": [
    "Kanaa",
    "Vada Chennai",
    "Neram",
    "Kootathil Oruthan",
    "Naanum Rowdydhaan",
    "Vennila Kabadi Kuzhu",
    "Aandavan Kattalai",
    "Oh My Kadavule",
    "Maanagaram",
    "Naan Sirithal"
],
'crime' : [
    "Dhuruvangal Pathinaaru",
    "Ratsasan",
    "Thunivu",
    "Kaithi",
    "Kavalai Vendam",
    "Imaikkaa Nodigal",
    "Vikram Vedha",
    "Anjaam Pathiraa",
    "Maanagaram",
    "Maha Samudram"]
}
print("Welcome to the Movie Recommendation App!\n")
seen_movies = {"eng": {}, "hindi": {}, "tamil": {}}
while True:
    lan = input("Choose a language for movie recommendations (eng/hindi/tamil): ").strip().lower()
    genre = input("Choose a genre (romance, horror, comedy, wholesome, action, crime, thriller): ").strip().lower()
    movie_dict = None
    if lan == 'eng':
        movie_dict = eng
    elif lan == 'hindi':
        movie_dict = hindi
    elif lan == 'tamil':
        movie_dict = tamil
    else:
        print("Language not recognized. Please choose 'eng', 'hindi', or 'tamil'.")
        continue
    if genre in movie_dict:
        if genre not in seen_movies[lan]:
            seen_movies[lan][genre] = set()
        available_movies = [m for m in movie_dict[genre] if m not in seen_movies[lan][genre]]
        
        if len(available_movies) >= 3:
            recommendations = r.sample(available_movies, k=3)
        elif available_movies:
            recommendations = available_movies  # Less than 3 movies left, suggest remaining
        else:
            print("No new recommendations available for this genre in your selected language. Try a different genre or language.")
            continue
        seen_movies[lan][genre].update(recommendations)
        print("\nHere are some recommended movies for you:")
        for movie in recommendations:
            print(f"- {movie}")
        print()
    else:
        print("Sorry, we don't have recommendations for this genre. Please try a different genre.\n")
    
    choice = input("Would you like another recommendation? (y/n): ").strip().lower()
    if choice != 'y':
        print("Thank you for using the Movie Recommendation App! Enjoy your movies!")
        break
# Out:
# Welcome to the Movie Recommendation App!
#
# Choose a language for movie recommendations (eng/hindi/tamil): ENG
# Choose a genre (romance, horror, comedy, wholesome, action, crime, thriller): romance
#
# Here are some recommended movies for you:
# - Silver Linings Playbook
# - The Notebook
# - Eternal Sunshine of the Spotless Mind
#
# Would you like another recommendation? (y/n): n
# Thank you for using the Movie Recommendation App! Enjoy your movies!
